# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# Load the Fashion MNIST dataset
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# Normalize each pixel intensity to be in the [0, 1] range.
X_train = train_images / 255.0

# Reshape the images to have a single channel
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
y_train = train_labels

# Normalize each pixel intensity to be in the [0, 1] range.
X_test = test_images / 255.0

# Reshape the images to have a single channel
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
y_test = test_labels

print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 1s 34us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 8s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 3s 1us/step
# Training data shape: (60000, 28, 28, 1)
# Testing data shape: (10000, 28, 28, 1)

# %%
# Dimensions of the image grid.
grid_width = 15
grid_height = 15

fig, axes = plt.subplots(grid_height, grid_width, figsize=(25, 25))
axes = axes.ravel()

for i in range(grid_height * grid_width):
    # Draft random index to get random image.
    index = np.random.randint(0, train_images.shape[0])
    axes[i].imshow(train_images[index], cmap='gray')
    # Show image class label above the drafted image.
    axes[i].set_title("Class: " + str(train_labels[index]), fontsize=8)
    axes[i].axis('off')
plt.subplots_adjust(hspace=0.4)

plt.show()

# %%
from tensorflow.keras import models, layers
cnn_model = models.Sequential()

cnn_model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
cnn_model.add(layers.MaxPool2D(pool_size=(2, 2)))

cnn_model.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn_model.add(layers.MaxPool2D(pool_size=(2, 2)))

cnn_model.add(layers.Conv2D(64, (3, 3), activation='relu'))

cnn_model.add(layers.Flatten())

# Each fully connected has half its input as its number of neurons.
cnn_model.add(layers.Dense(250, activation='relu'))
cnn_model.add(layers.Dense(125, activation='relu'))
cnn_model.add(layers.Dense(60, activation='relu'))

# 10 neurons in the last layer as we have 10 classes.
cnn_model.add(layers.Dense(10, activation='softmax'))

cnn_model.summary()
# Out:
# 2024-04-21 12:24:48.211604: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-04-21 12:24:48.213415: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pushkar-Nitro-AN515-54): /proc/driver/nvidia/version does not exist
# 2024-04-21 12:24:48.287823: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 250)               144250
#
#  dense_1 (Dense)             (None, 125)               31375
#
#  dense_2 (Dense)             (None, 60)                7560
#
#  dense_3 (Dense)             (None, 10)                610
#
# =================================================================
# Total params: 239,539
# Trainable params: 239,539
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import callbacks
early_stopping_callback = callbacks.EarlyStopping(patience=10)
batch_size = X_train.shape[0] // 20

cnn_model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy',
              metrics='accuracy')

import time
start_time = time.time()
# Fit model
epochs_info = cnn_model.fit(X_train,
                            y_train,
                            batch_size=batch_size,
                            epochs=500,
                            callbacks=[early_stopping_callback],
                            validation_split=0.15)
training_time = time.time() - start_time
# Out:
# Epoch 1/500
# 17/17 [==============================] - 20s 886ms/step - loss: 1.7527 - accuracy: 0.4091 - val_loss: 1.1031 - val_accuracy: 0.5651
# Epoch 2/500
# 17/17 [==============================] - 14s 815ms/step - loss: 0.9182 - accuracy: 0.6434 - val_loss: 0.7975 - val_accuracy: 0.6934
# Epoch 3/500
# 17/17 [==============================] - 14s 799ms/step - loss: 0.7473 - accuracy: 0.7195 - val_loss: 0.6850 - val_accuracy: 0.7471
# Epoch 4/500
# 17/17 [==============================] - 13s 795ms/step - loss: 0.6679 - accuracy: 0.7494 - val_loss: 0.6399 - val_accuracy: 0.7579
# Epoch 5/500
# 17/17 [==============================] - 15s 871ms/step - loss: 0.5994 - accuracy: 0.7734 - val_loss: 0.5712 - val_accuracy: 0.7821
# Epoch 6/500
# 17/17 [==============================] - 15s 898ms/step - loss: 0.5473 - accuracy: 0.7932 - val_loss: 0.5391 - val_accuracy: 0.7952
# Epoch 7/500
# 17/17 [==============================] - 14s 844ms/step - loss: 0.5168 - accuracy: 0.8044 - val_loss: 0.5193 - val_accuracy: 0.8039
# Epoch 8/500
# 17/17 [==============================] - 15s 880ms/step - loss: 0.4851 - accuracy: 0.8193 - val_loss: 0.4758 - val_accuracy: 0.8271
# Epoch 9/500
# 17/17 [==============================] - 15s 868ms/step - loss: 0.4625 - accuracy: 0.8282 - val_loss: 0.4558 - val_accuracy: 0.8298
# Epoch 10/500
# 17/17 [==============================] - 15s 868ms/step - loss: 0.4457 - accuracy: 0.8361 - val_loss: 0.4447 - val_accuracy: 0.8321
# Epoch 11/500
# 17/17 [==============================] - 15s 909ms/step - loss: 0.4256 - accuracy: 0.8439 - val_loss: 0.4285 - val_accuracy: 0.8424
# Epoch 12/500
# 17/17 [==============================] - 15s 906ms/step - loss: 0.4051 - accuracy: 0.8517 - val_loss: 0.4179 - val_accuracy: 0.8487
# Epoch 13/500
# 17/17 [==============================] - 15s 879ms/step - loss: 0.3965 - accuracy: 0.8559 - val_loss: 0.4017 - val_accuracy: 0.8563
# Epoch 14/500
# 17/17 [==============================] - 15s 861ms/step - loss: 0.3799 - accuracy: 0.8636 - val_loss: 0.4085 - val_accuracy: 0.8497
# Epoch 15/500
# 17/17 [==============================] - 15s 876ms/step - loss: 0.3706 - accuracy: 0.8653 - val_loss: 0.3995 - val_accuracy: 0.8541
# Epoch 16/500
# 17/17 [==============================] - 15s 885ms/step - loss: 0.3598 - accuracy: 0.8698 - val_loss: 0.3815 - val_accuracy: 0.8586
# Epoch 17/500
# 17/17 [==============================] - 15s 858ms/step - loss: 0.3501 - accuracy: 0.8728 - val_loss: 0.3680 - val_accuracy: 0.8683
# Epoch 18/500
# 17/17 [==============================] - 14s 851ms/step - loss: 0.3401 - accuracy: 0.8775 - val_loss: 0.3636 - val_accuracy: 0.8633
# Epoch 19/500
# 17/17 [==============================] - 15s 866ms/step - loss: 0.3352 - accuracy: 0.8789 - val_loss: 0.3496 - val_accuracy: 0.8734
# Epoch 20/500
# 17/17 [==============================] - 15s 891ms/step - loss: 0.3245 - accuracy: 0.8826 - val_loss: 0.3461 - val_accuracy: 0.8779
# Epoch 21/500
# 17/17 [==============================] - 15s 906ms/step - loss: 0.3230 - accuracy: 0.8812 - val_loss: 0.3575 - val_accuracy: 0.8723
# Epoch 22/500
# 17/17 [==============================] - 15s 898ms/step - loss: 0.3145 - accuracy: 0.8852 - val_loss: 0.3358 - val_accuracy: 0.8808
# Epoch 23/500
# 17/17 [==============================] - 15s 891ms/step - loss: 0.3119 - accuracy: 0.8863 - val_loss: 0.3379 - val_accuracy: 0.8778
# Epoch 24/500
# 17/17 [==============================] - 15s 886ms/step - loss: 0.3087 - accuracy: 0.8871 - val_loss: 0.3289 - val_accuracy: 0.8851
# Epoch 25/500
# 17/17 [==============================] - 14s 843ms/step - loss: 0.2991 - accuracy: 0.8906 - val_loss: 0.3249 - val_accuracy: 0.8826
# Epoch 26/500
# 17/17 [==============================] - 15s 860ms/step - loss: 0.2890 - accuracy: 0.8949 - val_loss: 0.3175 - val_accuracy: 0.8843
# Epoch 27/500
# 17/17 [==============================] - 14s 839ms/step - loss: 0.2829 - accuracy: 0.8963 - val_loss: 0.3179 - val_accuracy: 0.8883
# Epoch 28/500
# 17/17 [==============================] - 15s 901ms/step - loss: 0.2806 - accuracy: 0.8969 - val_loss: 0.3176 - val_accuracy: 0.8843
# Epoch 29/500
# 17/17 [==============================] - 16s 917ms/step - loss: 0.2822 - accuracy: 0.8957 - val_loss: 0.3372 - val_accuracy: 0.8763
# Epoch 30/500
# 17/17 [==============================] - 16s 924ms/step - loss: 0.2773 - accuracy: 0.8988 - val_loss: 0.3094 - val_accuracy: 0.8898
# Epoch 31/500
# 17/17 [==============================] - 15s 908ms/step - loss: 0.2722 - accuracy: 0.9004 - val_loss: 0.2978 - val_accuracy: 0.8904
# Epoch 32/500
# 17/17 [==============================] - 15s 880ms/step - loss: 0.2655 - accuracy: 0.9020 - val_loss: 0.3019 - val_accuracy: 0.8911
# Epoch 33/500
# 17/17 [==============================] - 15s 896ms/step - loss: 0.2619 - accuracy: 0.9031 - val_loss: 0.2953 - val_accuracy: 0.8938
# Epoch 34/500
# 17/17 [==============================] - 15s 882ms/step - loss: 0.2580 - accuracy: 0.9050 - val_loss: 0.2918 - val_accuracy: 0.8932
# Epoch 35/500
# 17/17 [==============================] - 16s 976ms/step - loss: 0.2558 - accuracy: 0.9061 - val_loss: 0.2951 - val_accuracy: 0.8923
# Epoch 36/500
# 17/17 [==============================] - 16s 948ms/step - loss: 0.2556 - accuracy: 0.9066 - val_loss: 0.2870 - val_accuracy: 0.8953
# Epoch 37/500
# 17/17 [==============================] - 15s 912ms/step - loss: 0.2443 - accuracy: 0.9107 - val_loss: 0.2853 - val_accuracy: 0.8979
# Epoch 38/500
# 17/17 [==============================] - 16s 917ms/step - loss: 0.2480 - accuracy: 0.9081 - val_loss: 0.2843 - val_accuracy: 0.8971
# Epoch 39/500
# 17/17 [==============================] - 16s 972ms/step - loss: 0.2429 - accuracy: 0.9107 - val_loss: 0.3008 - val_accuracy: 0.8899
# Epoch 40/500
# 17/17 [==============================] - 16s 948ms/step - loss: 0.2430 - accuracy: 0.9101 - val_loss: 0.2906 - val_accuracy: 0.8953
# Epoch 41/500
# 17/17 [==============================] - 16s 952ms/step - loss: 0.2428 - accuracy: 0.9112 - val_loss: 0.2893 - val_accuracy: 0.8923
# Epoch 42/500
# 17/17 [==============================] - 16s 956ms/step - loss: 0.2358 - accuracy: 0.9145 - val_loss: 0.2848 - val_accuracy: 0.8976
# Epoch 43/500
# 17/17 [==============================] - 16s 954ms/step - loss: 0.2308 - accuracy: 0.9151 - val_loss: 0.2819 - val_accuracy: 0.8959
# Epoch 44/500
# 17/17 [==============================] - 16s 958ms/step - loss: 0.2283 - accuracy: 0.9163 - val_loss: 0.2768 - val_accuracy: 0.8998
# Epoch 45/500
# 17/17 [==============================] - 17s 985ms/step - loss: 0.2302 - accuracy: 0.9146 - val_loss: 0.2830 - val_accuracy: 0.8981
# Epoch 46/500
# 17/17 [==============================] - 16s 948ms/step - loss: 0.2237 - accuracy: 0.9186 - val_loss: 0.2743 - val_accuracy: 0.9004
# Epoch 47/500
# 17/17 [==============================] - 16s 939ms/step - loss: 0.2329 - accuracy: 0.9140 - val_loss: 0.2933 - val_accuracy: 0.8922
# Epoch 48/500
# 17/17 [==============================] - 16s 958ms/step - loss: 0.2286 - accuracy: 0.9153 - val_loss: 0.2735 - val_accuracy: 0.9004
# Epoch 49/500
# 17/17 [==============================] - 16s 933ms/step - loss: 0.2222 - accuracy: 0.9179 - val_loss: 0.2703 - val_accuracy: 0.9011
# Epoch 50/500
# 17/17 [==============================] - 16s 972ms/step - loss: 0.2149 - accuracy: 0.9212 - val_loss: 0.2668 - val_accuracy: 0.9030
# Epoch 51/500
# 17/17 [==============================] - 15s 876ms/step - loss: 0.2106 - accuracy: 0.9228 - val_loss: 0.2673 - val_accuracy: 0.9027
# Epoch 52/500
# 17/17 [==============================] - 16s 945ms/step - loss: 0.2068 - accuracy: 0.9244 - val_loss: 0.2849 - val_accuracy: 0.8969
# Epoch 53/500
# 17/17 [==============================] - 16s 919ms/step - loss: 0.2077 - accuracy: 0.9243 - val_loss: 0.2685 - val_accuracy: 0.9027
# Epoch 54/500
# 17/17 [==============================] - 16s 922ms/step - loss: 0.2048 - accuracy: 0.9246 - val_loss: 0.2651 - val_accuracy: 0.9031
# Epoch 55/500
# 17/17 [==============================] - 16s 915ms/step - loss: 0.2005 - accuracy: 0.9265 - val_loss: 0.2627 - val_accuracy: 0.9062
# Epoch 56/500
# 17/17 [==============================] - 16s 922ms/step - loss: 0.1994 - accuracy: 0.9271 - val_loss: 0.2688 - val_accuracy: 0.8983
# Epoch 57/500
# 17/17 [==============================] - 16s 918ms/step - loss: 0.2005 - accuracy: 0.9271 - val_loss: 0.2852 - val_accuracy: 0.8974
# Epoch 58/500
# 17/17 [==============================] - 16s 920ms/step - loss: 0.2007 - accuracy: 0.9252 - val_loss: 0.2606 - val_accuracy: 0.9048
# Epoch 59/500
# 17/17 [==============================] - 16s 925ms/step - loss: 0.1959 - accuracy: 0.9274 - val_loss: 0.2660 - val_accuracy: 0.9031
# Epoch 60/500
# 17/17 [==============================] - 16s 943ms/step - loss: 0.1913 - accuracy: 0.9300 - val_loss: 0.2723 - val_accuracy: 0.9008
# Epoch 61/500
# 17/17 [==============================] - 16s 933ms/step - loss: 0.1960 - accuracy: 0.9275 - val_loss: 0.2614 - val_accuracy: 0.9058
# Epoch 62/500
# 17/17 [==============================] - 15s 913ms/step - loss: 0.1882 - accuracy: 0.9305 - val_loss: 0.2599 - val_accuracy: 0.9041
# Epoch 63/500
# 17/17 [==============================] - 15s 908ms/step - loss: 0.1920 - accuracy: 0.9297 - val_loss: 0.2787 - val_accuracy: 0.8997
# Epoch 64/500
# 17/17 [==============================] - 16s 936ms/step - loss: 0.1871 - accuracy: 0.9306 - val_loss: 0.2609 - val_accuracy: 0.9054
# Epoch 65/500
# 17/17 [==============================] - 16s 972ms/step - loss: 0.1930 - accuracy: 0.9284 - val_loss: 0.2906 - val_accuracy: 0.8966
# Epoch 66/500
# 17/17 [==============================] - 17s 982ms/step - loss: 0.1904 - accuracy: 0.9293 - val_loss: 0.2728 - val_accuracy: 0.8999
# Epoch 67/500
# 17/17 [==============================] - 16s 945ms/step - loss: 0.1847 - accuracy: 0.9322 - val_loss: 0.2571 - val_accuracy: 0.9076
# Epoch 68/500
# 17/17 [==============================] - 16s 961ms/step - loss: 0.1814 - accuracy: 0.9334 - val_loss: 0.2621 - val_accuracy: 0.9030
# Epoch 69/500
# 17/17 [==============================] - 16s 970ms/step - loss: 0.1778 - accuracy: 0.9349 - val_loss: 0.2581 - val_accuracy: 0.9064
# Epoch 70/500
# 17/17 [==============================] - 15s 908ms/step - loss: 0.1738 - accuracy: 0.9365 - val_loss: 0.2659 - val_accuracy: 0.9024
# Epoch 71/500
# 17/17 [==============================] - 17s 989ms/step - loss: 0.1705 - accuracy: 0.9386 - val_loss: 0.2567 - val_accuracy: 0.9053
# Epoch 72/500
# 17/17 [==============================] - 17s 998ms/step - loss: 0.1691 - accuracy: 0.9382 - val_loss: 0.2605 - val_accuracy: 0.9041
# Epoch 73/500
# 17/17 [==============================] - 17s 1s/step - loss: 0.1667 - accuracy: 0.9385 - val_loss: 0.2701 - val_accuracy: 0.9044
# Epoch 74/500
# 17/17 [==============================] - 18s 1s/step - loss: 0.1668 - accuracy: 0.9382 - val_loss: 0.2626 - val_accuracy: 0.9028
# Epoch 75/500
# 17/17 [==============================] - 21s 1s/step - loss: 0.1698 - accuracy: 0.9374 - val_loss: 0.2639 - val_accuracy: 0.9030
# Epoch 76/500
# 17/17 [==============================] - 18s 1s/step - loss: 0.1671 - accuracy: 0.9389 - val_loss: 0.2715 - val_accuracy: 0.9041
# Epoch 77/500
# 17/17 [==============================] - 17s 984ms/step - loss: 0.1579 - accuracy: 0.9426 - val_loss: 0.2556 - val_accuracy: 0.9094
# Epoch 78/500
# 17/17 [==============================] - 16s 960ms/step - loss: 0.1547 - accuracy: 0.9439 - val_loss: 0.2634 - val_accuracy: 0.9041
# Epoch 79/500
# 17/17 [==============================] - 16s 926ms/step - loss: 0.1574 - accuracy: 0.9427 - val_loss: 0.2730 - val_accuracy: 0.9010
# Epoch 80/500
# 17/17 [==============================] - 16s 926ms/step - loss: 0.1577 - accuracy: 0.9424 - val_loss: 0.2565 - val_accuracy: 0.9092
# Epoch 81/500
# 17/17 [==============================] - 16s 970ms/step - loss: 0.1486 - accuracy: 0.9468 - val_loss: 0.2578 - val_accuracy: 0.9079
# Epoch 82/500
# 17/17 [==============================] - 16s 943ms/step - loss: 0.1483 - accuracy: 0.9467 - val_loss: 0.2554 - val_accuracy: 0.9070
# Epoch 83/500
# 17/17 [==============================] - 16s 919ms/step - loss: 0.1542 - accuracy: 0.9428 - val_loss: 0.2610 - val_accuracy: 0.9073
# Epoch 84/500
# 17/17 [==============================] - 16s 916ms/step - loss: 0.1441 - accuracy: 0.9478 - val_loss: 0.2593 - val_accuracy: 0.9081
# Epoch 85/500
# 17/17 [==============================] - 16s 920ms/step - loss: 0.1408 - accuracy: 0.9491 - val_loss: 0.2622 - val_accuracy: 0.9067
# Epoch 86/500
# 17/17 [==============================] - 16s 963ms/step - loss: 0.1382 - accuracy: 0.9501 - val_loss: 0.2886 - val_accuracy: 0.9012
# Epoch 87/500
# 17/17 [==============================] - 15s 901ms/step - loss: 0.1513 - accuracy: 0.9438 - val_loss: 0.2581 - val_accuracy: 0.9071
# Epoch 88/500
# 17/17 [==============================] - 16s 954ms/step - loss: 0.1388 - accuracy: 0.9503 - val_loss: 0.2862 - val_accuracy: 0.8992
# Epoch 89/500
# 17/17 [==============================] - 16s 955ms/step - loss: 0.1423 - accuracy: 0.9479 - val_loss: 0.2630 - val_accuracy: 0.9058
# Epoch 90/500
# 17/17 [==============================] - 16s 967ms/step - loss: 0.1361 - accuracy: 0.9510 - val_loss: 0.2647 - val_accuracy: 0.9057
# Epoch 91/500
# 17/17 [==============================] - 15s 873ms/step - loss: 0.1323 - accuracy: 0.9526 - val_loss: 0.2685 - val_accuracy: 0.9058
# Epoch 92/500
# 17/17 [==============================] - 15s 887ms/step - loss: 0.1304 - accuracy: 0.9530 - val_loss: 0.2689 - val_accuracy: 0.9078

# %%
print(f"Training Time: {training_time:.2f} seconds")
# Out:
# Training Time: 1447.01 seconds

# %%
plt.plot(epochs_info.history['loss'])
plt.plot(epochs_info.history['val_loss'])
plt.title("CNN Model Loss Progression During Training")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Training loss", "Validation loss"])
plt.show()

# %%
plt.plot(epochs_info.history['accuracy'])
plt.plot(epochs_info.history['val_accuracy'])
plt.title("CNN Model Accuracy Progression During Training")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Training accuracy", "Validation accuracy"])
plt.show()

# %%
start_time = time.time()
cnn_model.evaluate(X_test, y_test)
testing_time = time.time() - start_time
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2865 - accuracy: 0.9062

# %%
start_time = time.time()
cnn_model.evaluate(X_test, y_test)
testing_time = time.time() - start_time
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2865 - accuracy: 0.9062

# %%
print(f"Testing Time: {testing_time:.2f} seconds")
# Out:
# Testing Time: 1.87 seconds

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
y_pred = cnn_model.predict(X_test)

# Get the class with highest predicted probability and assume it is the
# model prediction.
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred_classes)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d')
plt.title("CNN Model Prediction Confusion Matrix")
plt.show()
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
class_names = ["Class 0 => T-shirt",
               "Class 1 => Trouser",
               "Class 2 => Pullover",
               "Class 3 => Dress",
               "Class 4 => Coat",
               "Class 5 => Sandal",
               "Class 6 => Shirt",
               "Class 7 => Sneaker",
               "Class 8 => Bag",
               "Class 9 => Ankle boot"]
print(classification_report(y_test, y_pred_classes, target_names=class_names))
# Out:
#                        precision    recall  f1-score   support
#
#    Class 0 => T-shirt       0.81      0.90      0.85      1000
#    Class 1 => Trouser       0.99      0.98      0.99      1000
#   Class 2 => Pullover       0.90      0.82      0.86      1000
#      Class 3 => Dress       0.90      0.93      0.91      1000
#       Class 4 => Coat       0.83      0.87      0.85      1000
#     Class 5 => Sandal       0.98      0.98      0.98      1000
#      Class 6 => Shirt       0.75      0.69      0.72      1000
#    Class 7 => Sneaker       0.95      0.97      0.96      1000
#        Class 8 => Bag       0.97      0.98      0.98      1000
# Class 9 => Ankle boot       0.98      0.95      0.97      1000
#
#              accuracy                           0.91     10000
#             macro avg       0.91      0.91      0.91     10000
#          weighted avg       0.91      0.91      0.91     10000

# %%
grid_height = 15
grid_width = 15

fig, axes = plt.subplots(grid_height, grid_width, figsize=(25, 25))
axes = axes.ravel()

for i in range(grid_height * grid_width):
    # Draft random index to plot random image.
    drafted_image = np.random.randint(0, X_test.shape[0])
    axes[i].imshow(X_test[drafted_image].reshape(28, 28), cmap='gray')
    # Print actual and predicted labels for image.
    axes[i].set_title("Actual class: {:0.1f}\nPredicted class: {:0.1f}".format(
        y_test[drafted_image], y_pred_classes[drafted_image]), fontsize=8)
    axes[i].axis('off')
plt.subplots_adjust(hspace=0.8)

# %%
from tensorflow.keras.models import load_model, save_model
cnn_model.save(r"/home/pushkar/Desktop/dl_model_save/new_fashion.h5")

# %%
#random image classifi
import time

# Assuming cnn_model is your trained model

# Select a random index from the test data
random_index = np.random.randint(0, len(X_test))

# Get the random image and its corresponding label
random_image = X_test[random_index]
true_label = y_test[random_index]

# Start the timer
start_time = time.time()

# Make predictions on the random image
prediction = cnn_model.predict(np.expand_dims(random_image, axis=0))

# End the timer
end_time = time.time()

# Get the predicted label
predicted_label = np.argmax(prediction)

# Print the testing time
testing_time = end_time - start_time
print(f"Testing Time: {testing_time:.2f} seconds")

# Display the random image and its true and predicted labels
plt.imshow(random_image.squeeze(), cmap='gray')
plt.title(f"True Label: {true_label}, Predicted Label: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 59ms/step
# Testing Time: 0.13 seconds

# %%
#test data gui
import tkinter as tk
from tkinter import ttk
from PIL import Image, ImageTk
import numpy as np
import time
from tensorflow.keras.models import load_model

# Load the trained model
cnn_model = load_model(r"/home/pushkar/Desktop/dl_model_save/new_fashion.h5")

# Function to predict a random image
def predict_random_image():
    # Select a random index from the test data
    random_index = np.random.randint(0, len(X_test))
    # Get the random image and its corresponding label
    random_image = X_test[random_index]
    true_label = y_test[random_index]
    
    # Start the timer
    start_time = time.time()
    
    # Make predictions on the random image
    prediction = cnn_model.predict(np.expand_dims(random_image, axis=0))
    
    # End the timer
    end_time = time.time()
    
    # Get the predicted label
    predicted_label = np.argmax(prediction)
    
    # Print the testing time
    testing_time = end_time - start_time
    print(f"Testing Time: {testing_time:.2f} seconds")
    
    # Display the image and its labels in the GUI
    img = Image.fromarray(random_image.squeeze() * 255)  # Convert image array to PIL image
    img = img.resize((200, 200))  # Resize image for display
    
    # Update the image in the GUI
    photo = ImageTk.PhotoImage(img)
    image_label.config(image=photo)
    image_label.image = photo
    
    # Update the labels in the GUI
    true_label_var.set(f"True Label: {true_label}")
    predicted_label_var.set(f"Predicted Label: {predicted_label}")

# Create a Tkinter window
root = tk.Tk()
root.title("Random Image Predictor")

# Load your test data here
# Assuming X_test and y_test are defined

# Create GUI elements
image_frame = ttk.Frame(root)
image_frame.pack(padx=10, pady=10)

image_label = ttk.Label(image_frame)
image_label.pack()

true_label_var = tk.StringVar()
true_label_label = ttk.Label(root, textvariable=true_label_var)
true_label_label.pack()

predicted_label_var = tk.StringVar()
predicted_label_label = ttk.Label(root, textvariable=predicted_label_var)
predicted_label_label.pack()

predict_button = ttk.Button(root, text="Predict Random Image", command=predict_random_image)
predict_button.pack(pady=10)

# Run the Tkinter event loop
root.mainloop()
# Out:
# 1/1 [==============================] - 0s 111ms/step
# Testing Time: 0.16 seconds
# 1/1 [==============================] - 0s 29ms/step
# Testing Time: 0.09 seconds
# 1/1 [==============================] - 0s 29ms/step
# Testing Time: 0.08 seconds

# %%
#gui color input image
import tkinter as tk
from tkinter import ttk, filedialog
from PIL import Image, ImageTk
import numpy as np
import time
from tensorflow.keras.models import load_model

# Load the trained model
cnn_model = load_model(r"C:\Users\Admin\Downloads\dl_model\new_fashion.h5")
# def predict_image():
#     # Open file dialog to select an image file
#     file_path = filedialog.askopenfilename(filetypes=[("PNG files", "*.png")])
#     if file_path:
#         # Load and preprocess the image
#         img = Image.open(file_path).convert('L')  # Convert to grayscale
#         img = img.resize((28, 28))  # Resize image to match model input shape
#         img = np.array(img)
#         img = img.reshape((1, 28, 28, 1))  # Add batch dimension
        
#         # Start the timer
#         start_time = time.time()
        
#         # Make predictions on the image
#         prediction = cnn_model.predict(img)
        
#         # End the timer
#         end_time = time.time()
        
#         # Get the predicted label
#         predicted_label = np.argmax(prediction)
        
#         # Print the prediction and time taken
#         prediction_label.config(text=f"Predicted Label: {predicted_label}")
#         prediction_time.config(text=f"Prediction Time: {end_time - start_time:.2f} seconds")

#         # Display the uploaded image
#         img = Image.open(file_path)
#         img = img.resize((200, 200))
#         photo = ImageTk.PhotoImage(img)
#         uploaded_image_label.config(image=photo)
#         uploaded_image_label.image = photo
class_names = [
    "T-shirt",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]

def predict_image():
    # Open file dialog to select an image file
    file_path = filedialog.askopenfilename(filetypes=[("PNG files", "*.png")])
    if file_path:
        # Load and preprocess the image
        img = Image.open(file_path).convert('L')  # Convert to grayscale
        img = img.resize((28, 28))  # Resize image to match model input shape
        img = np.array(img)
        img = img.reshape((1, 28, 28, 1))  # Add batch dimension
        
        # Start the timer
        start_time = time.time()
        
        # Make predictions on the image
        prediction = cnn_model.predict(img)
        
        # End the timer
        end_time = time.time()
        
        # Get the predicted label
        predicted_label_index = np.argmax(prediction)
        predicted_label_name = class_names[predicted_label_index]
        
        # Print the prediction and time taken
        prediction_label.config(text=f"Predicted Label: {predicted_label_name}")
        prediction_time.config(text=f"Prediction Time: {end_time - start_time:.2f} seconds")

        # Display the uploaded image
        img = Image.open(file_path)
        img = img.resize((200, 200))
        photo = ImageTk.PhotoImage(img)
        uploaded_image_label.config(image=photo)
        uploaded_image_label.image = photo

# Create a Tkinter window
root = tk.Tk()
root.title("Image Label Prediction")

# Create GUI elements
upload_button = ttk.Button(root, text="Upload Image", command=predict_image)
upload_button.pack(pady=10)

uploaded_image_label = ttk.Label(root)
uploaded_image_label.pack()

prediction_label = ttk.Label(root, text="Predicted Label: ")
prediction_label.pack()

prediction_time = ttk.Label(root, text="Prediction Time: ")
prediction_time.pack()

# Run the Tkinter event loop
root.mainloop()
